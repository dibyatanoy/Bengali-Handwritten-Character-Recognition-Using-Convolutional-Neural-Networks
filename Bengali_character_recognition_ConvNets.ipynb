# %% [markdown]
# ---
# ### Using Convolutional Neural Networks to Improve Performance
#
# Convolutional neural networks are a relatively new topic, so there is little work applying this technique to Bengali character recognition. To the best of my knowledge, the only such work is by Akhand et. al, and even this applies an architecture identical to LeNet. More recent developments, such as dropout, have not been included in the architecture. In addition, the size of their dataset is ~17500 - about a fourth of the size of the augmented dataset I am using for this work.
#
# ---

# %%
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
import tensorflow as tf
from IPython.display import display, Image
from scipy import ndimage
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle
from PIL import Image
from six.moves import range

# Config the matlotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
pickle_file = 'bengaliOCR.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (50000, 50, 50) (50000,)
# Validation set (5000, 50, 50) (5000,)
# Test set (3000, 50, 50) (3000,)

# %%
image_size = 50
num_labels = 50
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (50000, 50, 50, 1) (50000, 50)
# Validation set (5000, 50, 50, 1) (5000, 50)
# Test set (3000, 50, 50, 1) (3000, 50)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %%
def simple_conv_net():
    
    batch_size = 128
    patch_size = 5
    depth = 16
    num_hidden = 64
    beta = 0.0005

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, num_channels, depth], stddev=0.1))
      layer1_biases = tf.Variable(tf.zeros([depth]))
      layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, depth, depth], stddev=0.1))
      layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
      layer3_weights = tf.Variable(tf.truncated_normal(
          [((image_size + 3) // 4) * ((image_size + 3) // 4) * depth, num_hidden], stddev=0.1))
      layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_labels], stddev=0.1))
      layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

      # Model.
      def model(data):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(conv + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

      # Training computation.
      logits = model(tf_train_dataset)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

      # Optimizer.
      optimizer = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(logits)
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
      test_prediction = tf.nn.softmax(model(tf_test_dataset))
        
      num_steps = 4001

      with tf.Session(graph=graph) as session:
        tf.initialize_all_variables().run()
        print('Initialized')
        for step in range(num_steps):
          offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
          batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
          batch_labels = train_labels[offset:(offset + batch_size), :]
          feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
          _, l, predictions = session.run(
            [optimizer, loss, train_prediction], feed_dict=feed_dict)
          if (step % 50 == 0):
            print('Minibatch loss at step %d: %f' % (step, l))
            print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
            print('Validation accuracy: %.1f%%' % accuracy(
              valid_prediction.eval(), valid_labels))
        print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))


simple_conv_net()
# Out:
# Initialized
# Minibatch loss at step 0: 7.028752
# Minibatch accuracy: 1.6%
# Validation accuracy: 1.8%
# Minibatch loss at step 50: 3.437618
# Minibatch accuracy: 10.2%
# Validation accuracy: 15.2%
# Minibatch loss at step 100: 2.135003
# Minibatch accuracy: 40.6%
# Validation accuracy: 32.4%
# Minibatch loss at step 150: 1.966478
# Minibatch accuracy: 40.6%
# Validation accuracy: 41.2%
# Minibatch loss at step 200: 1.669408
# Minibatch accuracy: 56.2%
# Validation accuracy: 52.1%
# Minibatch loss at step 250: 1.505720
# Minibatch accuracy: 58.6%
# Validation accuracy: 59.1%
# Minibatch loss at step 300: 1.238354
# Minibatch accuracy: 66.4%
# Validation accuracy: 62.4%
# Minibatch loss at step 350: 1.189107
# Minibatch accuracy: 68.0%
# Validation accuracy: 63.8%
# Minibatch loss at step 400: 0.977941
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.9%
# Minibatch loss at step 450: 0.939125
# Minibatch accuracy: 71.1%
# Validation accuracy: 69.0%
# Minibatch loss at step 500: 0.794241
# Minibatch accuracy: 71.9%
# Validation accuracy: 72.3%
# Minibatch loss at step 550: 0.733561
# Minibatch accuracy: 77.3%
# Validation accuracy: 75.4%
# Minibatch loss at step 600: 0.800874
# Minibatch accuracy: 77.3%
# Validation accuracy: 76.8%
# Minibatch loss at step 650: 0.616691
# Minibatch accuracy: 83.6%
# Validation accuracy: 79.5%
# Minibatch loss at step 700: 0.668907
# Minibatch accuracy: 82.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 750: 0.747245
# Minibatch accuracy: 77.3%
# Validation accuracy: 78.8%
# Minibatch loss at step 800: 0.737438
# Minibatch accuracy: 78.9%
# Validation accuracy: 78.6%
# Minibatch loss at step 850: 0.579642
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.7%
# Minibatch loss at step 900: 0.504740
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.9%
# Minibatch loss at step 950: 0.565681
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 1000: 0.348493
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.9%
# Minibatch loss at step 1050: 0.316943
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 1100: 0.387364
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.7%
# Minibatch loss at step 1150: 0.360448
# Minibatch accuracy: 88.3%
# Validation accuracy: 85.6%
# Minibatch loss at step 1200: 0.229160
# Minibatch accuracy: 89.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 1250: 0.254175
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.4%
# Minibatch loss at step 1300: 0.254908
# Minibatch accuracy: 91.4%
# Validation accuracy: 86.9%
# Minibatch loss at step 1350: 0.373766
# Minibatch accuracy: 89.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 1400: 0.416864
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.5%
# Minibatch loss at step 1450: 0.329560
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.2%
# Minibatch loss at step 1500: 0.206593
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 1550: 0.286926
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.3%
# Minibatch loss at step 1600: 0.407121
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.7%
# Minibatch loss at step 1650: 0.390913
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 1700: 0.173046
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 1750: 0.288460
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.1%
# Minibatch loss at step 1800: 0.178403
# Minibatch accuracy: 94.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 1850: 0.139391
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.7%
# Minibatch loss at step 1900: 0.174564
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 1950: 0.222184
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 2000: 0.136830
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.7%
# Minibatch loss at step 2050: 0.249923
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.1%
# Minibatch loss at step 2100: 0.107880
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 2150: 0.098490
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.1%
# Minibatch loss at step 2200: 0.222236
# Minibatch accuracy: 93.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 2250: 0.239654
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 2300: 0.138982
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 2350: 0.293488
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.9%
# Minibatch loss at step 2400: 0.120337
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 2450: 0.138833
# Minibatch accuracy: 96.9%
# Validation accuracy: 90.5%
# Minibatch loss at step 2500: 0.156186
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.9%
# Minibatch loss at step 2550: 0.073198
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 2600: 0.164515
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.3%
# Minibatch loss at step 2650: 1.058842
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.7%
# Minibatch loss at step 2700: 0.239720
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 2750: 0.188611
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.3%
# Minibatch loss at step 2800: 0.174582
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 2850: 0.200314
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 2900: 0.106326
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 2950: 0.064310
# Minibatch accuracy: 97.7%
# Validation accuracy: 93.1%
# Minibatch loss at step 3000: 0.077700
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.5%
# Minibatch loss at step 3050: 0.058891
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.6%
# Minibatch loss at step 3100: 0.092576
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 3150: 0.053091
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.3%
# Minibatch loss at step 3200: 0.033082
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 3250: 0.114426
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 3300: 0.061942
# Minibatch accuracy: 97.7%
# Validation accuracy: 91.6%
# Minibatch loss at step 3350: 0.094528
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 3400: 0.036651
# Minibatch accuracy: 99.2%
# Validation accuracy: 93.1%
# Minibatch loss at step 3450: 0.064026
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.6%
# Minibatch loss at step 3500: 0.163369
# Minibatch accuracy: 94.5%
# Validation accuracy: 93.2%
# Minibatch loss at step 3550: 0.041168
# Minibatch accuracy: 97.7%
# Validation accuracy: 93.3%
# Minibatch loss at step 3600: 0.089195
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 3650: 0.112126
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 3700: 0.062959
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.5%
# Minibatch loss at step 3750: 0.058040
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.3%
# Minibatch loss at step 3800: 0.063938
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.2%
# Minibatch loss at step 3850: 0.026558
# Minibatch accuracy: 99.2%
# Validation accuracy: 93.1%
# Minibatch loss at step 3900: 0.031272
# Minibatch accuracy: 99.2%
# Validation accuracy: 93.1%
# Minibatch loss at step 3950: 0.034271
# Minibatch accuracy: 99.2%
# Validation accuracy: 94.6%
# Minibatch loss at step 4000: 0.032187
# Minibatch accuracy: 99.2%
# Validation accuracy: 94.1%
# Test accuracy: 86.5%

# %% [markdown]
# ---
#
# Using a simple convolutional neural network, with only 2 convolution layers and 1 hidden layer, has surpassed the 85.96% limit achieved by the only work on Bengali character recognition involving conv-nets that I know of. Next, I plan to introduce max-pooling and dropout (to prevent overfitting), together with learning rate decay.
#
# ---

# %%
def improved_conv_net():
    
    batch_size = 128
    patch_size = 5
    depth = 16
    num_hidden = 64
    keep_prob = 0.75
    decay_step = 1000
    base = 0.86

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, num_channels, depth], stddev=0.1))
      layer1_biases = tf.Variable(tf.zeros([depth]))
      layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, depth, depth], stddev=0.1))
      layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
      layer3_weights = tf.Variable(tf.truncated_normal(
          [((image_size + 3) // 4) * ((image_size + 3) // 4) * depth, num_hidden], stddev=0.1))
      layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_labels], stddev=0.1))
      layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
        
      global_step = tf.Variable(0)  # count the number of steps taken.
      learning_rate = tf.train.exponential_decay(0.2, global_step, decay_step, base)

        
      # Model.
      def model(data, useDropout):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        if useDropout == 1:
            dropout_layer2 = tf.nn.dropout(reshape, keep_prob)
        else:
            dropout_layer2 = reshape
        hidden = tf.nn.relu(tf.matmul(dropout_layer2, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

      # Training computation.
      logits = model(tf_train_dataset, 1)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

      # Optimizer.
      optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(model(tf_train_dataset, 0))
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 0))
      test_prediction = tf.nn.softmax(model(tf_test_dataset, 0))
        
        
        
    num_steps = 5001

    with tf.Session(graph=graph) as session:
      tf.initialize_all_variables().run()
      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels)) 
    
improved_conv_net()
# Out:
# Initialized
# Minibatch loss at step 0: 9.439020
# Minibatch accuracy: 1.6%
# Validation accuracy: 2.0%
# Minibatch loss at step 50: 4.036674
# Minibatch accuracy: 0.0%
# Validation accuracy: 2.6%
# Minibatch loss at step 100: 3.485963
# Minibatch accuracy: 13.3%
# Validation accuracy: 12.1%
# Minibatch loss at step 150: 2.829701
# Minibatch accuracy: 29.7%
# Validation accuracy: 32.1%
# Minibatch loss at step 200: 2.451549
# Minibatch accuracy: 43.8%
# Validation accuracy: 35.6%
# Minibatch loss at step 250: 2.242574
# Minibatch accuracy: 41.4%
# Validation accuracy: 45.5%
# Minibatch loss at step 300: 1.880883
# Minibatch accuracy: 50.0%
# Validation accuracy: 48.4%
# Minibatch loss at step 350: 1.994727
# Minibatch accuracy: 46.9%
# Validation accuracy: 51.3%
# Minibatch loss at step 400: 1.582346
# Minibatch accuracy: 57.0%
# Validation accuracy: 52.5%
# Minibatch loss at step 450: 1.701735
# Minibatch accuracy: 52.3%
# Validation accuracy: 53.7%
# Minibatch loss at step 500: 1.918860
# Minibatch accuracy: 56.2%
# Validation accuracy: 53.4%
# Minibatch loss at step 550: 1.248959
# Minibatch accuracy: 67.2%
# Validation accuracy: 57.7%
# Minibatch loss at step 600: 1.487361
# Minibatch accuracy: 63.3%
# Validation accuracy: 58.9%
# Minibatch loss at step 650: 1.573710
# Minibatch accuracy: 62.5%
# Validation accuracy: 60.2%
# Minibatch loss at step 700: 1.478092
# Minibatch accuracy: 58.6%
# Validation accuracy: 65.2%
# Minibatch loss at step 750: 1.384782
# Minibatch accuracy: 71.9%
# Validation accuracy: 64.3%
# Minibatch loss at step 800: 1.427762
# Minibatch accuracy: 60.2%
# Validation accuracy: 68.1%
# Minibatch loss at step 850: 1.471380
# Minibatch accuracy: 63.3%
# Validation accuracy: 68.8%
# Minibatch loss at step 900: 1.161950
# Minibatch accuracy: 68.0%
# Validation accuracy: 72.2%
# Minibatch loss at step 950: 1.199341
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.6%
# Minibatch loss at step 1000: 1.070726
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.8%
# Minibatch loss at step 1050: 1.011271
# Minibatch accuracy: 74.2%
# Validation accuracy: 71.8%
# Minibatch loss at step 1100: 0.796964
# Minibatch accuracy: 79.7%
# Validation accuracy: 75.4%
# Minibatch loss at step 1150: 0.913738
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.7%
# Minibatch loss at step 1200: 0.829966
# Minibatch accuracy: 86.7%
# Validation accuracy: 75.7%
# Minibatch loss at step 1250: 0.647411
# Minibatch accuracy: 82.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 1300: 0.945706
# Minibatch accuracy: 73.4%
# Validation accuracy: 76.2%
# Minibatch loss at step 1350: 0.850493
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 1400: 1.096046
# Minibatch accuracy: 74.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 1450: 0.758632
# Minibatch accuracy: 84.4%
# Validation accuracy: 80.0%
# Minibatch loss at step 1500: 0.705903
# Minibatch accuracy: 85.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 1550: 0.982365
# Minibatch accuracy: 77.3%
# Validation accuracy: 74.6%
# Minibatch loss at step 1600: 0.844619
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.8%
# Minibatch loss at step 1650: 0.899365
# Minibatch accuracy: 72.7%
# Validation accuracy: 80.5%
# Minibatch loss at step 1700: 0.659850
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.8%
# Minibatch loss at step 1750: 0.601033
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.8%
# Minibatch loss at step 1800: 0.622704
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.3%
# Minibatch loss at step 1850: 0.443995
# Minibatch accuracy: 89.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 1900: 0.710760
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1950: 0.688356
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.6%
# Minibatch loss at step 2000: 0.939889
# Minibatch accuracy: 73.4%
# Validation accuracy: 83.3%
# Minibatch loss at step 2050: 0.683869
# Minibatch accuracy: 83.6%
# Validation accuracy: 83.2%
# Minibatch loss at step 2100: 0.554101
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.6%
# Minibatch loss at step 2150: 0.583892
# Minibatch accuracy: 86.7%
# Validation accuracy: 85.5%
# Minibatch loss at step 2200: 0.359157
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 2250: 0.604983
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 2300: 0.448140
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.4%
# Minibatch loss at step 2350: 0.698580
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 2400: 0.450126
# Minibatch accuracy: 89.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 2450: 0.565810
# Minibatch accuracy: 86.7%
# Validation accuracy: 86.5%
# Minibatch loss at step 2500: 0.383070
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 2550: 0.458682
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.2%
# Minibatch loss at step 2600: 0.546558
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 2650: 0.464433
# Minibatch accuracy: 91.4%
# Validation accuracy: 87.4%
# Minibatch loss at step 2700: 0.506387
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.6%
# Minibatch loss at step 2750: 0.511262
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.2%
# Minibatch loss at step 2800: 0.771982
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.3%
# Minibatch loss at step 2850: 0.471515
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.1%
# Minibatch loss at step 2900: 0.484683
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.1%
# Minibatch loss at step 2950: 0.381748
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.1%
# Minibatch loss at step 3000: 0.462731
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.6%
# Minibatch loss at step 3050: 0.500341
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.7%
# Minibatch loss at step 3100: 0.427931
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 3150: 0.253441
# Minibatch accuracy: 96.1%
# Validation accuracy: 89.6%
# Minibatch loss at step 3200: 0.314594
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 3250: 0.357581
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 3300: 0.621223
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 3350: 0.380803
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 3400: 0.293175
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.3%
# Minibatch loss at step 3450: 0.394905
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 3500: 0.340847
# Minibatch accuracy: 95.3%
# Validation accuracy: 90.5%
# Minibatch loss at step 3550: 0.314465
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 3600: 0.678737
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 3650: 0.551050
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.1%
# Minibatch loss at step 3700: 0.343719
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.0%
# Minibatch loss at step 3750: 0.425453
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.8%
# Minibatch loss at step 3800: 0.274485
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.0%
# Minibatch loss at step 3850: 0.373882
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 3900: 0.234591
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 3950: 0.318954
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 4000: 0.395231
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 4050: 0.206940
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 4100: 0.371489
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 4150: 0.326560
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 4200: 0.312061
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 4250: 0.192444
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 4300: 0.394601
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.3%
# Minibatch loss at step 4350: 0.335667
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 4400: 0.271023
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 4450: 0.368157
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 4500: 0.265225
# Minibatch accuracy: 94.5%
# Validation accuracy: 93.1%
# Minibatch loss at step 4550: 0.250698
# Minibatch accuracy: 96.1%
# Validation accuracy: 93.3%
# Minibatch loss at step 4600: 0.170539
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.4%
# Minibatch loss at step 4650: 0.303900
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.9%
# Minibatch loss at step 4700: 0.257810
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 4750: 0.290766
# Minibatch accuracy: 93.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 4800: 0.281650
# Minibatch accuracy: 93.0%
# Validation accuracy: 93.3%
# Minibatch loss at step 4850: 0.245819
# Minibatch accuracy: 96.1%
# Validation accuracy: 93.7%
# Minibatch loss at step 4900: 0.266041
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 4950: 0.186860
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 5000: 0.187956
# Minibatch accuracy: 94.5%
# Validation accuracy: 93.9%
# Test accuracy: 89.4%

# %% [markdown]
# ---
#
# Test accuracy has gone up to <b>89.4%</b>, a very significant improvement. The next steps would be to try and add more layers, fine-tune the hyperparameters, train for longer periods, and/ or introduce inception modules (I am really starting to wish I had a GPU).
#
# <img src = "result_screenshots/small_conv_net.png">
#
# ---

# %%
def improved_conv_net_2():
    
    batch_size = 64
    patch_size = 5
    depth = 16
    num_hidden = 64
    num_hidden2 = 32
    keep_prob = 0.75
    decay_step = 1000
    base = 0.86

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, num_channels, depth], stddev=0.1))
      layer1_biases = tf.Variable(tf.zeros([depth]))
      layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size, patch_size, depth, depth], stddev=0.1))
      layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
      layer3_weights = tf.Variable(tf.truncated_normal(
          [((image_size + 3) // 4) * ((image_size + 3) // 4) * depth, num_hidden], stddev=0.1))
      layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_hidden2], stddev=0.1))
      layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))
      layer5_weights = tf.Variable(tf.truncated_normal(
          [num_hidden2, num_labels], stddev=0.1))
      layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
        
      global_step = tf.Variable(0)  # count the number of steps taken.
      learning_rate = tf.train.exponential_decay(0.2, global_step, decay_step, base)

        
      # Model.
      def model(data, useDropout):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        if useDropout == 1:
            dropout_layer2 = tf.nn.dropout(reshape, keep_prob)
        else:
            dropout_layer2 = reshape
        hidden = tf.nn.relu(tf.matmul(dropout_layer2, layer3_weights) + layer3_biases)
        
        hidden = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
        return tf.matmul(hidden, layer5_weights) + layer5_biases

      # Training computation.
      logits = model(tf_train_dataset, 1)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

      # Optimizer.
      optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(model(tf_train_dataset, 0))
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 0))
      test_prediction = tf.nn.softmax(model(tf_test_dataset, 0))
        
        
        
    num_steps = 20001

    with tf.Session(graph=graph) as session:
      tf.initialize_all_variables().run()
      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels)) 
    
improved_conv_net_2()
# Out:
# Initialized
# Minibatch loss at step 0: 4.790777
# Minibatch accuracy: 6.2%
# Validation accuracy: 2.0%
# Minibatch loss at step 50: 3.597866
# Minibatch accuracy: 14.1%
# Validation accuracy: 9.4%
# Minibatch loss at step 100: 3.398741
# Minibatch accuracy: 20.3%
# Validation accuracy: 14.0%
# Minibatch loss at step 150: 2.600026
# Minibatch accuracy: 31.2%
# Validation accuracy: 28.0%
# Minibatch loss at step 200: 2.330626
# Minibatch accuracy: 31.2%
# Validation accuracy: 33.1%
# Minibatch loss at step 250: 2.453974
# Minibatch accuracy: 39.1%
# Validation accuracy: 38.0%
# Minibatch loss at step 300: 2.006609
# Minibatch accuracy: 48.4%
# Validation accuracy: 40.5%
# Minibatch loss at step 350: 1.797950
# Minibatch accuracy: 45.3%
# Validation accuracy: 47.1%
# Minibatch loss at step 400: 1.405292
# Minibatch accuracy: 60.9%
# Validation accuracy: 52.5%
# Minibatch loss at step 450: 1.647349
# Minibatch accuracy: 59.4%
# Validation accuracy: 57.5%
# Minibatch loss at step 500: 1.530732
# Minibatch accuracy: 59.4%
# Validation accuracy: 55.9%
# Minibatch loss at step 550: 1.186659
# Minibatch accuracy: 62.5%
# Validation accuracy: 62.2%
# Minibatch loss at step 600: 0.941010
# Minibatch accuracy: 71.9%
# Validation accuracy: 66.9%
# Minibatch loss at step 650: 1.007234
# Minibatch accuracy: 67.2%
# Validation accuracy: 68.7%
# Minibatch loss at step 700: 1.402682
# Minibatch accuracy: 60.9%
# Validation accuracy: 67.5%
# Minibatch loss at step 750: 1.360101
# Minibatch accuracy: 65.6%
# Validation accuracy: 67.1%
# Minibatch loss at step 800: 0.858874
# Minibatch accuracy: 79.7%
# Validation accuracy: 72.8%
# Minibatch loss at step 850: 1.180007
# Minibatch accuracy: 65.6%
# Validation accuracy: 71.3%
# Minibatch loss at step 900: 0.993947
# Minibatch accuracy: 70.3%
# Validation accuracy: 76.1%
# Minibatch loss at step 950: 0.669963
# Minibatch accuracy: 79.7%
# Validation accuracy: 77.1%
# Minibatch loss at step 1000: 0.782618
# Minibatch accuracy: 82.8%
# Validation accuracy: 70.9%
# Minibatch loss at step 1050: 1.212702
# Minibatch accuracy: 70.3%
# Validation accuracy: 75.8%
# Minibatch loss at step 1100: 0.761494
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.7%
# Minibatch loss at step 1150: 0.747355
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 1200: 0.933542
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.2%
# Minibatch loss at step 1250: 0.736896
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 1300: 0.641243
# Minibatch accuracy: 82.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 1350: 0.599370
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 1400: 0.725079
# Minibatch accuracy: 82.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 1450: 0.769219
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 1500: 0.721789
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.6%
# Minibatch loss at step 1550: 0.882518
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 1600: 0.990963
# Minibatch accuracy: 78.1%
# Validation accuracy: 84.8%
# Minibatch loss at step 1650: 0.955478
# Minibatch accuracy: 71.9%
# Validation accuracy: 82.8%
# Minibatch loss at step 1700: 0.639992
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 1750: 0.508062
# Minibatch accuracy: 89.1%
# Validation accuracy: 83.1%
# Minibatch loss at step 1800: 0.437669
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 1850: 0.421932
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.4%
# Minibatch loss at step 1900: 0.549264
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 1950: 0.739234
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 2000: 0.334261
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 2050: 0.676069
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.7%
# Minibatch loss at step 2100: 0.333217
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 2150: 0.366988
# Minibatch accuracy: 95.3%
# Validation accuracy: 87.2%
# Minibatch loss at step 2200: 0.406412
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.1%
# Minibatch loss at step 2250: 0.579732
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 2300: 0.391864
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.4%
# Minibatch loss at step 2350: 0.266066
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.0%
# Minibatch loss at step 2400: 0.190852
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 2450: 0.395669
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 2500: 0.491187
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.2%
# Minibatch loss at step 2550: 0.642354
# Minibatch accuracy: 89.1%
# Validation accuracy: 85.9%
# Minibatch loss at step 2600: 0.350808
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.9%
# Minibatch loss at step 2650: 0.449346
# Minibatch accuracy: 92.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 2700: 0.322203
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 2750: 0.230095
# Minibatch accuracy: 95.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 2800: 0.375789
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 2850: 0.328138
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 2900: 0.488702
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 2950: 0.384563
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.9%
# Minibatch loss at step 3000: 0.311347
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.5%
# Minibatch loss at step 3050: 0.421060
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 3100: 0.373833
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# Minibatch loss at step 3150: 0.355996
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.2%
# Minibatch loss at step 3200: 0.286832
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 3250: 0.537836
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 3300: 0.258109
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.3%
# Minibatch loss at step 3350: 0.265420
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
# Minibatch loss at step 3400: 0.369566
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.1%
# Minibatch loss at step 3450: 0.489820
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 3500: 0.352774
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 3550: 0.216113
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.2%
# Minibatch loss at step 3600: 0.214760
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 3650: 0.251810
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 3700: 0.258079
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 3750: 0.379733
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 3800: 0.228503
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 3850: 0.116073
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 3900: 0.251324
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 3950: 0.219771
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.0%
# Minibatch loss at step 4000: 0.110778
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.4%
# Minibatch loss at step 4050: 0.154570
# Minibatch accuracy: 98.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 4100: 0.385977
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 4150: 0.196265
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 4200: 0.194907
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.6%
# Minibatch loss at step 4250: 0.225281
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 4300: 0.331295
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 4350: 0.211271
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 4400: 0.245578
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.2%
# Minibatch loss at step 4450: 0.459282
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 4500: 0.257537
# Minibatch accuracy: 92.2%
# Validation accuracy: 93.3%
# Minibatch loss at step 4550: 0.212339
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 4600: 0.145867
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 4650: 0.078615
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 4700: 0.203960
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.4%
# Minibatch loss at step 4750: 0.174225
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.4%
# Minibatch loss at step 4800: 0.421373
# Minibatch accuracy: 92.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 4850: 0.418187
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.2%
# Minibatch loss at step 4900: 0.401450
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.7%
# Minibatch loss at step 4950: 0.075965
# Minibatch accuracy: 100.0%
# Validation accuracy: 93.9%
# Minibatch loss at step 5000: 0.184146
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.5%
# Minibatch loss at step 5050: 0.158799
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.2%
# Minibatch loss at step 5100: 0.240767
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.5%
# Minibatch loss at step 5150: 0.272310
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 5200: 0.231286
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.5%
# Minibatch loss at step 5250: 0.145758
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.5%
# Minibatch loss at step 5300: 0.209803
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.4%
# Minibatch loss at step 5350: 0.123509
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.7%
# Minibatch loss at step 5400: 0.326735
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.5%
# Minibatch loss at step 5450: 0.244915
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.5%
# Minibatch loss at step 5500: 0.150345
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.8%
# Minibatch loss at step 5550: 0.164750
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.6%
# Minibatch loss at step 5600: 0.298709
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.9%
# Minibatch loss at step 5650: 0.219912
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.9%
# Minibatch loss at step 5700: 0.280121
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.2%
# Minibatch loss at step 5750: 0.067499
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.0%
# Minibatch loss at step 5800: 0.233713
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.5%
# Minibatch loss at step 5850: 0.226708
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.3%
# Minibatch loss at step 5900: 0.191010
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.3%
# Minibatch loss at step 5950: 0.180022
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.3%
# Minibatch loss at step 6000: 0.081526
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.6%
# Minibatch loss at step 6050: 0.208319
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.5%
# Minibatch loss at step 6100: 0.050768
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.2%
# Minibatch loss at step 6150: 0.174611
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.0%
# Minibatch loss at step 6200: 0.147382
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.5%
# Minibatch loss at step 6250: 0.171154
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.6%
# Minibatch loss at step 6300: 0.068402
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.9%
# Minibatch loss at step 6350: 0.280077
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.7%
# Minibatch loss at step 6400: 0.126294
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.5%
# Minibatch loss at step 6450: 0.103463
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.6%
# Minibatch loss at step 6500: 0.167996
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.6%
# Minibatch loss at step 6550: 0.169515
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.6%
# Minibatch loss at step 6600: 0.150160
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.5%
# Minibatch loss at step 6650: 0.329997
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.1%
# Minibatch loss at step 6700: 0.066646
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.5%
# Minibatch loss at step 6750: 0.061962
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.6%
# Minibatch loss at step 6800: 0.098318
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.7%
# Minibatch loss at step 6850: 0.200621
# Minibatch accuracy: 93.8%
# Validation accuracy: 94.7%
# Minibatch loss at step 6900: 0.124584
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.5%
# Minibatch loss at step 6950: 0.061897
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.0%
# Minibatch loss at step 7000: 0.075656
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.3%
# Minibatch loss at step 7050: 0.057176
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.3%
# Minibatch loss at step 7100: 0.119840
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.5%
# Minibatch loss at step 7150: 0.077440
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.9%
# Minibatch loss at step 7200: 0.178249
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.6%
# Minibatch loss at step 7250: 0.159954
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.3%
# Minibatch loss at step 7300: 0.256950
# Minibatch accuracy: 92.2%
# Validation accuracy: 95.3%
# Minibatch loss at step 7350: 0.329074
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.6%
# Minibatch loss at step 7400: 0.246287
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.2%
# Minibatch loss at step 7450: 0.146766
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.4%
# Minibatch loss at step 7500: 0.078024
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.5%
# Minibatch loss at step 7550: 0.084601
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.6%
# Minibatch loss at step 7600: 0.123199
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.4%
# Minibatch loss at step 7650: 0.078801
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.6%
# Minibatch loss at step 7700: 0.054264
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.7%
# Minibatch loss at step 7750: 0.221381
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.5%
# Minibatch loss at step 7800: 0.156208
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.1%
# Minibatch loss at step 7850: 0.038805
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.5%
# Minibatch loss at step 7900: 0.101155
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.7%
# Minibatch loss at step 7950: 0.153569
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.8%
# Minibatch loss at step 8000: 0.038729
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.6%
# Minibatch loss at step 8050: 0.068671
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.9%
# Minibatch loss at step 8100: 0.096486
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.8%
# Minibatch loss at step 8150: 0.096946
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.1%
# Minibatch loss at step 8200: 0.085387
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.7%
# Minibatch loss at step 8250: 0.153555
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.8%
# Minibatch loss at step 8300: 0.297446
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.4%
# Minibatch loss at step 8350: 0.054161
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 8400: 0.051543
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.2%
# Minibatch loss at step 8450: 0.099388
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 8500: 0.054617
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.1%
# Minibatch loss at step 8550: 0.225892
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.1%
# Minibatch loss at step 8600: 0.016621
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 8650: 0.254007
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.9%
# Minibatch loss at step 8700: 0.120462
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.7%
# Minibatch loss at step 8750: 0.147853
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.1%
# Minibatch loss at step 8800: 0.051891
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.0%
# Minibatch loss at step 8850: 0.166831
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 8900: 0.068190
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.9%
# Minibatch loss at step 8950: 0.095067
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.1%
# Minibatch loss at step
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.9%
# Minibatch loss at step 19750: 0.112388
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.7%
# Minibatch loss at step 19800: 0.053687
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 19850: 0.060032
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 19900: 0.042139
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.8%
# Minibatch loss at step 19950: 0.098039
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.7%
# Minibatch loss at step 20000: 0.064127
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.7%
# Test accuracy: 92.2%

# %% [markdown]
# ---
#
# Training for 2,000 more steps, while halving the batch size, has raised accuracy by 1%, allowing it to <b>cross the 90% limit</b>.
#
# <img src="result_screenshots/Conv_net_7000_steps.png">
#
# I plan to train the same neural network with 20,000 steps before introducing an inception module. I am also starting to think about augmenting the test dataset by throwing in some small random rotations.
#
# <b>Update:</b> Training the same neural network for 20000 steps, I managed to get an accuracy of <b>92.2%</b> on the test data. To the best of my knowledge, the only work on Bengali character recognition using convolutional nets achieved a maximum accuracy of 85.96%.
#
# <img src="result_screenshots/Conv_net_20000_steps.png">
#
# The next step would be to build an architecture with 1 or more inception modules, but I am uncertain how long it will take for the model to converge on my CPU.

# %%
def improved_conv_net_3():
    
    batch_size = 64
    patch_size1 = 3
    patch_size2 = 5
    depth = 16
    num_hidden = 64
    num_hidden2 = 32
    keep_prob = 0.5
    decay_step = 1000
    base = 0.86

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, num_channels, depth], stddev=0.5))
      layer1_biases = tf.Variable(tf.zeros([depth]))
      layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size2, patch_size2, depth, depth], stddev=0.1))
      layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
      layer3_weights = tf.Variable(tf.truncated_normal(
          [((image_size + 3) // 4) * ((image_size + 3) // 4) * depth, num_hidden], stddev=0.05))
      layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_hidden2], stddev=0.1))
      layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))
      layer5_weights = tf.Variable(tf.truncated_normal(
          [num_hidden2, num_labels], stddev=0.1))
      layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
        
      global_step = tf.Variable(0)  # count the number of steps taken.
      learning_rate = tf.train.exponential_decay(0.2, global_step, decay_step, base)

        
      # Model.
      def model(data, useDropout):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer2_biases)
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
        if useDropout == 1:
            dropout_layer2 = tf.nn.dropout(reshape, keep_prob)
        else:
            dropout_layer2 = reshape
        hidden = tf.nn.relu(tf.matmul(dropout_layer2, layer3_weights) + layer3_biases)
        
        hidden = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
        return tf.matmul(hidden, layer5_weights) + layer5_biases

      # Training computation.
      logits = model(tf_train_dataset, 1)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

      # Optimizer.
      optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(model(tf_train_dataset, 0))
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 0))
      test_prediction = tf.nn.softmax(model(tf_test_dataset, 0))
        
        
        
    num_steps = 30001

    with tf.Session(graph=graph) as session:
      tf.initialize_all_variables().run()
      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels)) 
    
improved_conv_net_3()
# Out:
# Initialized
# Minibatch loss at step 0: 4.512722
# Minibatch accuracy: 0.0%
# Validation accuracy: 2.5%
# Minibatch loss at step 50: 3.810328
# Minibatch accuracy: 3.1%
# Validation accuracy: 6.5%
# Minibatch loss at step 100: 3.385483
# Minibatch accuracy: 9.4%
# Validation accuracy: 14.0%
# Minibatch loss at step 150: 2.617777
# Minibatch accuracy: 34.4%
# Validation accuracy: 27.2%
# Minibatch loss at step 200: 2.221004
# Minibatch accuracy: 42.2%
# Validation accuracy: 37.6%
# Minibatch loss at step 250: 2.266766
# Minibatch accuracy: 40.6%
# Validation accuracy: 41.6%
# Minibatch loss at step 300: 1.763511
# Minibatch accuracy: 46.9%
# Validation accuracy: 49.8%
# Minibatch loss at step 350: 1.751924
# Minibatch accuracy: 54.7%
# Validation accuracy: 51.0%
# Minibatch loss at step 400: 1.479380
# Minibatch accuracy: 65.6%
# Validation accuracy: 55.9%
# Minibatch loss at step 450: 1.319004
# Minibatch accuracy: 67.2%
# Validation accuracy: 63.6%
# Minibatch loss at step 500: 1.299414
# Minibatch accuracy: 67.2%
# Validation accuracy: 64.3%
# Minibatch loss at step 550: 1.309586
# Minibatch accuracy: 60.9%
# Validation accuracy: 68.6%
# Minibatch loss at step 600: 1.262883
# Minibatch accuracy: 65.6%
# Validation accuracy: 48.8%
# Minibatch loss at step 650: 1.116626
# Minibatch accuracy: 71.9%
# Validation accuracy: 72.1%
# Minibatch loss at step 700: 1.153340
# Minibatch accuracy: 71.9%
# Validation accuracy: 74.0%
# Minibatch loss at step 750: 1.158007
# Minibatch accuracy: 70.3%
# Validation accuracy: 74.3%
# Minibatch loss at step 800: 1.369218
# Minibatch accuracy: 76.6%
# Validation accuracy: 72.9%
# Minibatch loss at step 850: 1.076125
# Minibatch accuracy: 71.9%
# Validation accuracy: 79.3%
# Minibatch loss at step 900: 0.944347
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.9%
# Minibatch loss at step 950: 0.790110
# Minibatch accuracy: 76.6%
# Validation accuracy: 78.8%
# Minibatch loss at step 1000: 0.896484
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 1050: 1.145685
# Minibatch accuracy: 76.6%
# Validation accuracy: 81.6%
# Minibatch loss at step 1100: 0.543275
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.2%
# Minibatch loss at step 1150: 0.907619
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 1200: 0.729743
# Minibatch accuracy: 76.6%
# Validation accuracy: 83.0%
# Minibatch loss at step 1250: 0.610527
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.6%
# Minibatch loss at step 1300: 0.818495
# Minibatch accuracy: 79.7%
# Validation accuracy: 78.7%
# Minibatch loss at step 1350: 0.527931
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.0%
# Minibatch loss at step 1400: 0.622164
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.3%
# Minibatch loss at step 1450: 0.686891
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 1500: 0.775163
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 1550: 0.659220
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 1600: 0.827723
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 1650: 0.698954
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 1700: 0.521448
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 1750: 0.596258
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 1800: 0.581547
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.6%
# Minibatch loss at step 1850: 0.348274
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 1900: 0.472863
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 1950: 0.783162
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 2000: 0.559736
# Minibatch accuracy: 92.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 2050: 0.791249
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 2100: 0.440127
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.4%
# Minibatch loss at step 2150: 0.447603
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.2%
# Minibatch loss at step 2200: 0.584138
# Minibatch accuracy: 95.3%
# Validation accuracy: 86.6%
# Minibatch loss at step 2250: 0.360811
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 2300: 0.552758
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.8%
# Minibatch loss at step 2350: 0.437410
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.6%
# Minibatch loss at step 2400: 0.482343
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.9%
# Minibatch loss at step 2450: 0.417199
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 2500: 0.674544
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.8%
# Minibatch loss at step 2550: 0.473530
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 2600: 0.383227
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.8%
# Minibatch loss at step 2650: 0.269331
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.1%
# Minibatch loss at step 2700: 0.411616
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 2750: 0.550625
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 2800: 0.668271
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 2850: 0.340182
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 2900: 0.466728
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 2950: 0.282364
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.5%
# Minibatch loss at step 3000: 0.451357
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.5%
# Minibatch loss at step 3050: 0.404029
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.1%
# Minibatch loss at step 3100: 0.466456
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.9%
# Minibatch loss at step 3150: 0.281678
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 3200: 0.190441
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.7%
# Minibatch loss at step 3250: 0.382505
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.4%
# Minibatch loss at step 3300: 0.425986
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.6%
# Minibatch loss at step 3350: 0.240240
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 3400: 0.313678
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.1%
# Minibatch loss at step 3450: 0.442442
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 3500: 0.385685
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.6%
# Minibatch loss at step 3550: 0.289433
# Minibatch accuracy: 100.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 3600: 0.324742
# Minibatch accuracy: 90.6%
# Validation accuracy: 93.0%
# Minibatch loss at step 3650: 0.441092
# Minibatch accuracy: 90.6%
# Validation accuracy: 93.1%
# Minibatch loss at step 3700: 0.256353
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.9%
# Minibatch loss at step 3750: 0.457992
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.8%
# Minibatch loss at step 3800: 0.271979
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.8%
# Minibatch loss at step 3850: 0.322608
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.3%
# Minibatch loss at step 3900: 0.385297
# Minibatch accuracy: 92.2%
# Validation accuracy: 93.6%
# Minibatch loss at step 3950: 0.386715
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.4%
# Minibatch loss at step 4000: 0.346893
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 4050: 0.167932
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.5%
# Minibatch loss at step 4100: 0.339479
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.5%
# Minibatch loss at step 4150: 0.163665
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.5%
# Minibatch loss at step 4200: 0.252815
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.8%
# Minibatch loss at step 4250: 0.296627
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.2%
# Minibatch loss at step 4300: 0.375285
# Minibatch accuracy: 90.6%
# Validation accuracy: 93.6%
# Minibatch loss at step 4350: 0.260523
# Minibatch accuracy: 93.8%
# Validation accuracy: 94.0%
# Minibatch loss at step 4400: 0.241278
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.4%
# Minibatch loss at step 4450: 0.176200
# Minibatch accuracy: 98.4%
# Validation accuracy: 94.4%
# Minibatch loss at step 4500: 0.160178
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.7%
# Minibatch loss at step 4550: 0.286921
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.0%
# Minibatch loss at step 4600: 0.130821
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.6%
# Minibatch loss at step 4650: 0.122111
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.1%
# Minibatch loss at step 4700: 0.247032
# Minibatch accuracy: 95.3%
# Validation accuracy: 94.9%
# Minibatch loss at step 4750: 0.317501
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.0%
# Minibatch loss at step 4800: 0.439747
# Minibatch accuracy: 92.2%
# Validation accuracy: 94.9%
# Minibatch loss at step 4850: 0.405862
# Minibatch accuracy: 93.8%
# Validation accuracy: 94.6%
# Minibatch loss at step 4900: 0.328564
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.9%
# Minibatch loss at step 4950: 0.192709
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.4%
# Minibatch loss at step 5000: 0.154809
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.4%
# Minibatch loss at step 5050: 0.276007
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.7%
# Minibatch loss at step 5100: 0.339237
# Minibatch accuracy: 96.9%
# Validation accuracy: 94.6%
# Minibatch loss at step 5150: 0.253734
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.0%
# Minibatch loss at step 5200: 0.082668
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.4%
# Minibatch loss at step 5250: 0.210725
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.4%
# Minibatch loss at step 5300: 0.105576
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.2%
# Minibatch loss at step 5350: 0.268211
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.3%
# Minibatch loss at step 5400: 0.484698
# Minibatch accuracy: 93.8%
# Validation accuracy: 94.0%
# Minibatch loss at step 5450: 0.216113
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.1%
# Minibatch loss at step 5500: 0.189132
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.8%
# Minibatch loss at step 5550: 0.226298
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.2%
# Minibatch loss at step 5600: 0.487957
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.7%
# Minibatch loss at step 5650: 0.282388
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.2%
# Minibatch loss at step 5700: 0.284842
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.5%
# Minibatch loss at step 5750: 0.163061
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.8%
# Minibatch loss at step 5800: 0.265127
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.8%
# Minibatch loss at step 5850: 0.201090
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.8%
# Minibatch loss at step 5900: 0.147203
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.7%
# Minibatch loss at step 5950: 0.178938
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.7%
# Minibatch loss at step 6000: 0.141696
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.6%
# Minibatch loss at step 6050: 0.191796
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.0%
# Minibatch loss at step 6100: 0.084648
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.3%
# Minibatch loss at step 6150: 0.229352
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.0%
# Minibatch loss at step 6200: 0.113478
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.3%
# Minibatch loss at step 6250: 0.110405
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.1%
# Minibatch loss at step 6300: 0.325440
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.4%
# Minibatch loss at step 6350: 0.197418
# Minibatch accuracy: 93.8%
# Validation accuracy: 96.1%
# Minibatch loss at step 6400: 0.239007
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.3%
# Minibatch loss at step 6450: 0.345492
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.4%
# Minibatch loss at step 6500: 0.259745
# Minibatch accuracy: 96.9%
# Validation accuracy: 95.7%
# Minibatch loss at step 6550: 0.194150
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.3%
# Minibatch loss at step 6600: 0.224612
# Minibatch accuracy: 95.3%
# Validation accuracy: 95.4%
# Minibatch loss at step 6650: 0.223748
# Minibatch accuracy: 98.4%
# Validation accuracy: 95.5%
# Minibatch loss at step 6700: 0.182233
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.1%
# Minibatch loss at step 6750: 0.220199
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 6800: 0.213230
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.5%
# Minibatch loss at step 6850: 0.369813
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.4%
# Minibatch loss at step 6900: 0.155621
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 6950: 0.080893
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.3%
# Minibatch loss at step 7000: 0.172023
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.1%
# Minibatch loss at step 7050: 0.153395
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 7100: 0.157538
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 7150: 0.088081
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.5%
# Minibatch loss at step 7200: 0.263018
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.6%
# Minibatch loss at step 7250: 0.193444
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.6%
# Minibatch loss at step 7300: 0.216512
# Minibatch accuracy: 95.3%
# Validation accuracy: 96.7%
# Minibatch loss at step 7350: 0.250776
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.7%
# Minibatch loss at step 7400: 0.271942
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.2%
# Minibatch loss at step 7450: 0.111654
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.2%
# Minibatch loss at step 7500: 0.390801
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.6%
# Minibatch loss at step 7550: 0.065153
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.6%
# Minibatch loss at step 7600: 0.118263
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.8%
# Minibatch loss at step 7650: 0.132193
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.6%
# Minibatch loss at step 7700: 0.174182
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 7750: 0.111011
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.6%
# Minibatch loss at step 7800: 0.131695
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.0%
# Minibatch loss at step 7850: 0.128916
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.0%
# Minibatch loss at step 7900: 0.075879
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.7%
# Minibatch loss at step 7950: 0.017654
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.9%
# Minibatch loss at step 8000: 0.141868
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.2%
# Minibatch loss at step 8050: 0.185046
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.9%
# Minibatch loss at step 8100: 0.130296
# Minibatch accuracy: 96.9%
# Validation accuracy: 96.7%
# Minibatch loss at step 8150: 0.095271
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.9%
# Minibatch loss at step 8200: 0.156916
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.8%
# Minibatch loss at step 8250: 0.124969
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.9%
# Minibatch loss at step 8300: 0.155797
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.0%
# Minibatch loss at step 8350: 0.128614
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.8%
# Minibatch loss at step 8400: 0.143916
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 8450: 0.076601
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.0%
# Minibatch loss at step 8500: 0.164708
# Minibatch accuracy: 98.4%
# Validation accuracy: 96.8%
# Minibatch loss at step 8550: 0.186054
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.0%
# Minibatch loss at step 8600: 0.036928
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.2%
# Minibatch loss at step 8650: 0.140436
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.8%
# Minibatch loss at step 8700: 0.123125
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.4%
# Minibatch loss at step 8750: 0.221063
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.3%
# Minibatch loss at step 8800: 0.133457
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.9%
# Minibatch loss at step 8850: 0.188854
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.2%
# Minibatch loss at step 8900: 0.293683
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 8950: 0.084947
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.0%
# Minibatch loss at step 9000: 0.111095
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.9%
# Minibatch loss at step 9050: 0.179118
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.2%
# Minibatch loss at step 9100: 0.163756
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.3%
# Minibatch loss at step 9150: 0.122611
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.5%
# Minibatch loss at step 9200: 0.195237
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.4%
# Minibatch loss at step 9250: 0.148230
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.0%
# Minibatch loss at step 9300: 0.260723
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.4%
# Minibatch loss at step 9350: 0.034898
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.1%
# Minibatch loss at step 9400: 0.228113
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.4%
# Minibatch loss at step 9450: 0.109611
# Minibatch accuracy: 96.9%
# Validation accuracy: 97.2%
# Minibatch loss at step 9500: 0.059804
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.2%
# Minibatch loss at step 9550: 0.149244
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.1%
# Minibatch loss at step 9600: 0.068528
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.1%
# Minibatch loss at step 9650: 0.155030
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.2%
# Minibatch loss at step 9700: 0.062044
# Minibatch accuracy: 96.9%
# Validation accuracy: 97.2%
# Minibatch loss at step 9750: 0.097284
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 9800: 0.112841
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 9850: 0.151424
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.4%
# Minibatch loss at step 9900: 0.076566
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.1%
# Minibatch loss at step 9950: 0.210285
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.6%
# Minibatch loss at step 10000: 0.252104
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.4%
# Minibatch loss at step 10050: 0.085334
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.5%
# Minibatch loss at step 10100: 0.217723
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.7%
# Minibatch loss at step 10150: 0.120539
# Minibatch accuracy: 96.9%
# Validation accuracy: 97.5%
# Minibatch loss at step 10200: 0.116863
# Minibatch accuracy: 98.4%
# Validation accuracy: 97.6%
# Minibatch loss at step 10250: 0.139884
# Minibatch accuracy: 96.9%
# Validation accuracy: 97.3%
# Minibatch loss at step 10300: 0.064034
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.3%
# Minibatch loss at step 10350: 0.296918
# Minibatch accuracy: 93.8%
# Validation accuracy: 97.4%
# Minibatch loss at step 10400: 0.103758
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.4%
# Minibatch loss at step 10450: 0.139250
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.5%
# Minibatch loss at step 10500: 0.033663
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.4%
# Minibatch loss at step 10550: 0.037368
# Minibatch accuracy: 100.0%
# Validation accuracy: 97.7%
# Minibatch loss at step
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 28100: 0.052546
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 28150: 0.081912
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 28200: 0.106550
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 28250: 0.123877
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 28300: 0.087522
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 28350: 0.087772
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 28400: 0.041576
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 28450: 0.025716
# Minibatch accuracy: 98.4%
# Validation accuracy: 98.6%
# Minibatch loss at step 28500: 0.031135
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 28550: 0.056370
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 28600: 0.050859
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 28650: 0.180022
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.7%
# Minibatch loss at step 28700: 0.065101
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 28750: 0.034472
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 28800: 0.046901
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 28850: 0.081630
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 28900: 0.037235
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 28950: 0.111393
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29000: 0.081804
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29050: 0.082029
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29100: 0.055430
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29150: 0.105793
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 29200: 0.044247
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 29250: 0.025588
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 29300: 0.131086
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.5%
# Minibatch loss at step 29350: 0.064862
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29400: 0.024048
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29450: 0.040434
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29500: 0.120706
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29550: 0.097401
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29600: 0.136364
# Minibatch accuracy: 98.4%
# Validation accuracy: 98.6%
# Minibatch loss at step 29650: 0.038636
# Minibatch accuracy: 98.4%
# Validation accuracy: 98.6%
# Minibatch loss at step 29700: 0.104496
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29750: 0.033308
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29800: 0.096161
# Minibatch accuracy: 98.4%
# Validation accuracy: 98.6%
# Minibatch loss at step 29850: 0.044923
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29900: 0.087357
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 29950: 0.054274
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Minibatch loss at step 30000: 0.131493
# Minibatch accuracy: 100.0%
# Validation accuracy: 98.6%
# Test accuracy: 93.5%

# %% [markdown]
# ---
#
# I tried a slightly different architecture in which the first convolutional layer used 3x3 patches instead of 5x5. My reasoning was that such a convolutional layer would capture and preserve a little more detail with respect to the small dots that form the only distinction between a lot of Bengali character pairs (for instance, ড and ড়). I also used a keep-probability of 0.5 in the dropout layer, instead of 0.75. All of this did help improve performance quite a lot. Test set accuracy is now up to <b>93.5%</b>. Validation accuracy is at 98.6%, and it is reasonable to conclude that this specific model has converged.
#
# <img src="result_screenshots/Conv_net_3x3.png">
#
# I also noted that the change to the validation accuracy after 20,000 steps was almost non-existent, so this architecture actually worked better - the accuracy did not increase simply because it was allowed to run for more steps.
#
# ---

# %%
def conv_net_with_inception():
    
    batch_size = 64
    patch_size1 = 3
    patch_size2 = 5
    depth1 = 16
    depth2 = 8
    depth3= 4
    concat_depth = 24
    num_hidden = 64
    num_hidden2 = 32
    keep_prob = 0.5
    decay_step = 1000
    base = 0.86

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, num_channels, depth1], stddev=0.5))
      layer1_biases = tf.Variable(tf.zeros([depth1]))
      
      layer3_weights = tf.Variable(tf.truncated_normal(
          [((image_size + 3) // 4) * ((image_size + 3) // 4) * concat_depth, num_hidden], stddev=0.05))
      layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_hidden2], stddev=0.1))
      layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))
      layer5_weights = tf.Variable(tf.truncated_normal(
          [num_hidden2, num_labels], stddev=0.1))
      layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
        
        
      inception1x1_weights = tf.Variable(tf.truncated_normal(
          [1, 1, depth1, depth2], stddev=0.2))
      inception1x1_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
      inception3x3_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, depth2, depth3], stddev=0.1))
      inception3x3_biases = tf.Variable(tf.constant(1.0, shape=[depth3]))
      inception5x5_weights = tf.Variable(tf.truncated_normal(
          [patch_size2, patch_size2, depth2, depth3], stddev=0.08))
      inception5x5_biases = tf.Variable(tf.constant(1.0, shape=[depth3]))
    
      inception1x1_post_mxpool_wts = tf.Variable(tf.truncated_normal(
          [1, 1, depth1, depth2], stddev=0.4))
      post_maxpool_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
      inception_biases = tf.Variable(tf.constant(1.0, shape=[concat_depth]))
        
      global_step = tf.Variable(0)  # count the number of steps taken.
      learning_rate = tf.train.exponential_decay(0.2, global_step, decay_step, base)

        
      # Model.
      def model(data, useDropout):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer1_biases)
        
        inception1x1_conv = tf.nn.conv2d(hidden, inception1x1_weights, [1, 1, 1, 1], padding='SAME')
        inception1x1_relu = tf.nn.relu(inception1x1_conv + inception1x1_biases)
        
        inception3x3_conv = tf.nn.conv2d(inception1x1_relu, inception3x3_weights, [1, 1, 1, 1], padding='SAME')
        inception3x3_relu = tf.nn.relu(inception3x3_conv + inception3x3_biases)
        
        inception5x5_conv = tf.nn.conv2d(inception1x1_relu, inception5x5_weights, [1, 1, 1, 1], padding='SAME')
        inception5x5_relu = tf.nn.relu(inception5x5_conv + inception5x5_biases)
        
        inception3x3_maxpool = tf.nn.max_pool(hidden, [1, 3, 3, 1], [1, 1, 1, 1], padding='SAME')
        inception1x1_post_maxpool = tf.nn.conv2d(inception3x3_maxpool, inception1x1_post_mxpool_wts, [1, 1, 1, 1], padding='SAME')
        inception1x1_post_maxpool = tf.nn.relu(inception1x1_post_maxpool + post_maxpool_biases)
        
        concat_filter = tf.concat(3, [inception1x1_relu, inception3x3_relu, inception5x5_relu, inception1x1_post_maxpool])
        concat_maxpooled = tf.nn.max_pool(concat_filter, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = concat_maxpooled.get_shape().as_list()
        
        reshape = tf.reshape(concat_maxpooled, [shape[0], shape[1] * shape[2] * shape[3]])
        if useDropout == 1:
            dropout_layer2 = tf.nn.dropout(tf.nn.relu(reshape), keep_prob)
        else:
            dropout_layer2 = tf.nn.relu(reshape)
        hidden = tf.nn.relu(tf.matmul(dropout_layer2, layer3_weights) + layer3_biases)
        
        hidden = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
        return tf.matmul(hidden, layer5_weights) + layer5_biases

      # Training computation.
      logits = model(tf_train_dataset, 1)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

      # Optimizer.
      optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(model(tf_train_dataset, 0))
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 0))
      test_prediction = tf.nn.softmax(model(tf_test_dataset, 0))
        
        
        
    num_steps = 6001

    with tf.Session(graph=graph) as session:
      tf.initialize_all_variables().run()
      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels)) 
    
conv_net_with_inception()
# Out:
# Initialized
# Minibatch loss at step 0: 4.633584
# Minibatch accuracy: 3.1%
# Validation accuracy: 2.0%
# Minibatch loss at step 50: 3.899493
# Minibatch accuracy: 4.7%
# Validation accuracy: 2.3%
# Minibatch loss at step 100: 3.930233
# Minibatch accuracy: 0.0%
# Validation accuracy: 2.2%
# Minibatch loss at step 150: 3.905514
# Minibatch accuracy: 3.1%
# Validation accuracy: 3.4%
# Minibatch loss at step 200: 3.545082
# Minibatch accuracy: 7.8%
# Validation accuracy: 12.2%
# Minibatch loss at step 250: 3.169687
# Minibatch accuracy: 14.1%
# Validation accuracy: 17.1%
# Minibatch loss at step 300: 2.904961
# Minibatch accuracy: 20.3%
# Validation accuracy: 22.6%
# Minibatch loss at step 350: 2.456557
# Minibatch accuracy: 29.7%
# Validation accuracy: 29.9%
# Minibatch loss at step 400: 1.876747
# Minibatch accuracy: 37.5%
# Validation accuracy: 35.8%
# Minibatch loss at step 450: 1.989218
# Minibatch accuracy: 54.7%
# Validation accuracy: 42.5%
# Minibatch loss at step 500: 2.034309
# Minibatch accuracy: 35.9%
# Validation accuracy: 46.3%
# Minibatch loss at step 550: 1.682619
# Minibatch accuracy: 45.3%
# Validation accuracy: 56.6%
# Minibatch loss at step 600: 1.343249
# Minibatch accuracy: 65.6%
# Validation accuracy: 49.2%
# Minibatch loss at step 650: 1.298232
# Minibatch accuracy: 59.4%
# Validation accuracy: 58.7%
# Minibatch loss at step 700: 1.513748
# Minibatch accuracy: 53.1%
# Validation accuracy: 61.6%
# Minibatch loss at step 750: 1.676823
# Minibatch accuracy: 60.9%
# Validation accuracy: 56.4%
# Minibatch loss at step 800: 1.428597
# Minibatch accuracy: 70.3%
# Validation accuracy: 60.2%
# Minibatch loss at step 850: 1.483022
# Minibatch accuracy: 60.9%
# Validation accuracy: 69.1%
# Minibatch loss at step 900: 1.350170
# Minibatch accuracy: 67.2%
# Validation accuracy: 68.1%
# Minibatch loss at step 950: 1.031333
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.0%
# Minibatch loss at step 1000: 0.791395
# Minibatch accuracy: 78.1%
# Validation accuracy: 72.1%
# Minibatch loss at step 1050: 1.374214
# Minibatch accuracy: 65.6%
# Validation accuracy: 74.2%
# Minibatch loss at step 1100: 1.212119
# Minibatch accuracy: 71.9%
# Validation accuracy: 69.9%
# Minibatch loss at step 1150: 1.840240
# Minibatch accuracy: 53.1%
# Validation accuracy: 62.1%
# Minibatch loss at step 1200: 0.892452
# Minibatch accuracy: 78.1%
# Validation accuracy: 76.8%
# Minibatch loss at step 1250: 0.853801
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.2%
# Minibatch loss at step 1300: 0.978999
# Minibatch accuracy: 78.1%
# Validation accuracy: 65.7%
# Minibatch loss at step 1350: 0.587893
# Minibatch accuracy: 89.1%
# Validation accuracy: 77.7%
# Minibatch loss at step 1400: 0.919925
# Minibatch accuracy: 78.1%
# Validation accuracy: 77.4%
# Minibatch loss at step 1450: 0.819704
# Minibatch accuracy: 85.9%
# Validation accuracy: 76.2%
# Minibatch loss at step 1500: 0.766662
# Minibatch accuracy: 82.8%
# Validation accuracy: 76.7%
# Minibatch loss at step 1550: 0.839983
# Minibatch accuracy: 76.6%
# Validation accuracy: 79.3%
# Minibatch loss at step 1600: 1.305859
# Minibatch accuracy: 65.6%
# Validation accuracy: 81.5%
# Minibatch loss at step 1650: 1.255651
# Minibatch accuracy: 70.3%
# Validation accuracy: 80.2%
# Minibatch loss at step 1700: 0.748626
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.2%
# Minibatch loss at step 1750: 0.547996
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 1800: 0.628045
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.2%
# Minibatch loss at step 1850: 0.683683
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.4%
# Minibatch loss at step 1900: 0.929900
# Minibatch accuracy: 79.7%
# Validation accuracy: 83.6%
# Minibatch loss at step 1950: 0.853934
# Minibatch accuracy: 76.6%
# Validation accuracy: 84.2%
# Minibatch loss at step 2000: 0.673968
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 2050: 0.996515
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 2100: 0.310124
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.3%
# Minibatch loss at step 2150: 0.617408
# Minibatch accuracy: 85.9%
# Validation accuracy: 84.2%
# Minibatch loss at step 2200: 0.688175
# Minibatch accuracy: 89.1%
# Validation accuracy: 84.9%
# Minibatch loss at step 2250: 0.587477
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.3%
# Minibatch loss at step 2300: 0.416289
# Minibatch accuracy: 92.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 2350: 0.447480
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.9%
# Minibatch loss at step 2400: 0.523557
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.2%
# Minibatch loss at step 2450: 0.653146
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# Minibatch loss at step 2500: 0.837908
# Minibatch accuracy: 82.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 2550: 0.529389
# Minibatch accuracy: 89.1%
# Validation accuracy: 83.5%
# Minibatch loss at step 2600: 0.616370
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Minibatch loss at step 2650: 0.500318
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 2700: 0.349514
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 2750: 0.677518
# Minibatch accuracy: 82.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 2800: 0.641344
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# Minibatch loss at step 2850: 0.488157
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 2900: 0.450563
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 2950: 0.773602
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 3000: 0.629275
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 3050: 0.661196
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 3100: 0.568596
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 3150: 0.499054
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 3200: 0.412974
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 3250: 0.448290
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.9%
# Minibatch loss at step 3300: 0.466375
# Minibatch accuracy: 92.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 3350: 0.303964
# Minibatch accuracy: 95.3%
# Validation accuracy: 89.0%
# Minibatch loss at step 3400: 0.834674
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 3450: 0.550601
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.6%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-80320c6a0710> in <module>()
#     127       print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
#     128
# --> 129 conv_net_with_inception()
#     130
#
# <ipython-input-93-80320c6a0710> in conv_net_with_inception()
#     119         feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
#     120         _, l, predictions = session.run(
# --> 121           [optimizer, loss, train_prediction], feed_dict=feed_dict)
#     122         if (step % 50 == 0):
#     123           print('Minibatch loss at step %d: %f' % (step, l))
#
# /Library/Python/2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     338     try:
#     339       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 340                          run_metadata_ptr)
#     341       if run_metadata:
#     342         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Library/Python/2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     562     try:
#     563       results = self._do_run(handle, target_list, unique_fetches,
# --> 564                              feed_dict_string, options, run_metadata)
#     565     finally:
#     566       # The movers are no longer used. Delete them.
#
# /Library/Python/2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     635     if handle is None:
#     636       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 637                            target_list, options, run_metadata)
#     638     else:
#     639       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Library/Python/2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     642   def _do_call(self, fn, *args):
#     643     try:
# --> 644       return fn(*args)
#     645     except tf_session.StatusNotOK as e:
#     646       error_message = compat.as_text(e.error_message)
#
# /Library/Python/2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     626       else:
#     627         return tf_session.TF_Run(
# --> 628             session, None, feed_dict, fetch_list, target_list, None)
#     629
#     630     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
def deeper_inception_conv_net():
    
    batch_size = 50
    patch_size1 = 3
    patch_size2 = 5
    depth = 16
    depth1 = 32
    depth2 = 16
    depth3 = 8
    concat_depth = 48
    num_hidden = 64
    num_hidden2 = 32
    keep_prob = 0.5
    decay_step = 2000
    base = 0.9

    graph = tf.Graph()

    with graph.as_default():

      # Input data.
      tf_train_dataset = tf.placeholder(
        tf.float32, shape=(batch_size, image_size, image_size, num_channels))
      tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
      tf_valid_dataset = tf.constant(valid_dataset)
      tf_test_dataset = tf.constant(test_dataset)

      # Variables.
      layer1_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, num_channels, depth], stddev=0.3))
      layer1_biases = tf.Variable(tf.zeros([depth]))
      layer2_weights = tf.Variable(tf.truncated_normal(
          [patch_size2, patch_size2, depth, depth1], stddev=0.05))
      layer2_biases = tf.Variable(tf.constant(0.0, shape=[depth1]))
      layer3_weights = tf.Variable(tf.truncated_normal(
          [((image_size + 3) // 4) * ((image_size + 3) // 4) * concat_depth, num_hidden], stddev=0.05))
      layer3_biases = tf.Variable(tf.constant(0.0, shape=[num_hidden]))
      layer4_weights = tf.Variable(tf.truncated_normal(
          [num_hidden, num_hidden2], stddev=0.01))
      layer4_biases = tf.Variable(tf.constant(0.0, shape=[num_hidden2]))
      layer5_weights = tf.Variable(tf.truncated_normal(
          [num_hidden2, num_labels], stddev=0.01))
      layer5_biases = tf.Variable(tf.constant(0.0, shape=[num_labels]))
        
      inception1x1_weights = tf.Variable(tf.truncated_normal(
          [1, 1, depth1, depth2], stddev=0.25))
      inception1x1_biases = tf.Variable(tf.constant(0.0, shape=[depth2]))
      inception3x3_weights = tf.Variable(tf.truncated_normal(
          [patch_size1, patch_size1, depth2, depth3], stddev=0.05))
      inception3x3_biases = tf.Variable(tf.constant(0.0, shape=[depth3]))
      inception5x5_weights = tf.Variable(tf.truncated_normal(
          [patch_size2, patch_size2, depth2, depth3], stddev=0.08))
      inception5x5_biases = tf.Variable(tf.constant(0.0, shape=[depth3]))
    
      inception1x1_post_mxpool_wts = tf.Variable(tf.truncated_normal(
          [1, 1, depth1, depth2], stddev=0.04))
      post_maxpool_biases = tf.Variable(tf.constant(0.0, shape=[depth2]))
        
      global_step = tf.Variable(0, trainable = False)  # count the number of steps taken.
      learning_rate = tf.train.exponential_decay(0.005, global_step, decay_step, base)

        
      # Model.
      def model(data, useDropout):
        conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer1_biases)
        conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
        max_pooled = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(max_pooled + layer2_biases)
        
        inception1x1_conv = tf.nn.conv2d(hidden, inception1x1_weights, [1, 1, 1, 1], padding='SAME')
        inception1x1_relu = tf.nn.relu(inception1x1_conv + inception1x1_biases)
        
        inception3x3_conv = tf.nn.conv2d(inception1x1_relu, inception3x3_weights, [1, 1, 1, 1], padding='SAME')
        inception3x3_relu = tf.nn.relu(inception3x3_conv + inception3x3_biases)
        
        inception5x5_conv = tf.nn.conv2d(inception1x1_relu, inception5x5_weights, [1, 1, 1, 1], padding='SAME')
        inception5x5_relu = tf.nn.relu(inception5x5_conv + inception5x5_biases)
        
        inception3x3_maxpool = tf.nn.max_pool(hidden, [1, 3, 3, 1], [1, 1, 1, 1], padding='SAME')
        inception1x1_post_maxpool = tf.nn.conv2d(inception3x3_maxpool, inception1x1_post_mxpool_wts, [1, 1, 1, 1], padding='SAME')
        inception1x1_post_maxpool = tf.nn.relu(inception1x1_post_maxpool + post_maxpool_biases)
        
        concat_filter = tf.concat(3, [inception1x1_relu, inception3x3_relu, inception5x5_relu, inception1x1_post_maxpool])
        concat_maxpooled = tf.nn.max_pool(concat_filter, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = concat_maxpooled.get_shape().as_list()
        
        reshape = tf.reshape(concat_maxpooled, [shape[0], shape[1] * shape[2] * shape[3]])
    
        if useDropout == 1:
            dropout_layer2 = tf.nn.dropout(tf.nn.relu(reshape), keep_prob)
        else:
            dropout_layer2 = tf.nn.relu(reshape)
        hidden = tf.nn.relu(tf.matmul(dropout_layer2, layer3_weights) + layer3_biases)
        
        hidden = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
        return tf.matmul(hidden, layer5_weights) + layer5_biases

      # Training computation.
      logits = model(tf_train_dataset, 1)
      loss = tf.reduce_mean(
        tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

      # Optimizer.
      optimizer = tf.train.AdamOptimizer(0.001).minimize(loss, global_step=global_step)

      # Predictions for the training, validation, and test data.
      train_prediction = tf.nn.softmax(model(tf_train_dataset, 0))
      valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 0))
      test_prediction = tf.nn.softmax(model(tf_test_dataset, 0))
        
        
        
    num_steps = 30001

    with tf.Session(graph=graph) as session:
      tf.initialize_all_variables().run()
      print('Initialized')
      for step in range(num_steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
        _, l, predictions = session.run(
          [optimizer, loss, train_prediction], feed_dict=feed_dict)
        if (step % 50 == 0):
          print('Minibatch loss at step %d: %f' % (step, l))
          print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
          #print(tf.Print(layer1_weights, [layer1_weights]).eval())
          print('Validation accuracy: %.1f%%' % accuracy(
            valid_prediction.eval(), valid_labels))
      print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels)) 
    
deeper_inception_conv_net()
# Out:
# Initialized
# Minibatch loss at step 0: 3.911899
# Minibatch accuracy: 0.0%
# Validation accuracy: 2.0%
# Minibatch loss at step 50: 3.897340
# Minibatch accuracy: 8.0%
# Validation accuracy: 3.2%
# Minibatch loss at step 100: 3.077546
# Minibatch accuracy: 14.0%
# Validation accuracy: 15.0%
# Minibatch loss at step 150: 2.567519
# Minibatch accuracy: 26.0%
# Validation accuracy: 27.4%
# Minibatch loss at step 200: 2.237518
# Minibatch accuracy: 32.0%
# Validation accuracy: 39.2%
# Minibatch loss at step 250: 2.060417
# Minibatch accuracy: 38.0%
# Validation accuracy: 46.1%
# Minibatch loss at step 300: 1.688675
# Minibatch accuracy: 54.0%
# Validation accuracy: 52.9%
# Minibatch loss at step 350: 1.270563
# Minibatch accuracy: 64.0%
# Validation accuracy: 58.6%
# Minibatch loss at step 400: 1.312693
# Minibatch accuracy: 58.0%
# Validation accuracy: 61.0%
# Minibatch loss at step 450: 1.214476
# Minibatch accuracy: 72.0%
# Validation accuracy: 66.9%
# Minibatch loss at step 500: 0.895895
# Minibatch accuracy: 70.0%
# Validation accuracy: 69.7%
# Minibatch loss at step 550: 1.026531
# Minibatch accuracy: 62.0%
# Validation accuracy: 68.4%
# Minibatch loss at step 600: 0.930266
# Minibatch accuracy: 82.0%
# Validation accuracy: 72.1%
# Minibatch loss at step 650: 1.157339
# Minibatch accuracy: 70.0%
# Validation accuracy: 72.6%
# Minibatch loss at step 700: 0.651844
# Minibatch accuracy: 80.0%
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.4%
# Minibatch loss at step 4950: 0.164562
# Minibatch accuracy: 94.0%
# Validation accuracy: 94.0%
# Minibatch loss at step 5000: 0.214511
# Minibatch accuracy: 92.0%
# Validation accuracy: 94.4%
# Minibatch loss at step 5050: 0.175150
# Minibatch accuracy: 98.0%
# Validation accuracy: 94.3%
# Minibatch loss at step 5100: 0.091036
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.2%
# Minibatch loss at step 5150: 0.094858
# Minibatch accuracy: 96.0%
# Validation accuracy: 94.6%
# Minibatch loss at step 5200: 0.269684
# Minibatch accuracy: 96.0%
# Validation accuracy: 94.5%
# Minibatch loss at step 5250: 0.224361
# Minibatch accuracy: 96.0%
# Validation accuracy: 95.3%
# Minibatch loss at step 5300: 0.137828
# Minibatch accuracy: 96.0%
# Validation accuracy: 94.4%
# Minibatch loss at step 5350: 0.142663
# Minibatch accuracy: 96.0%
# Validation accuracy: 94.9%
# Minibatch loss at step 5400: 0.131958
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.8%
# Minibatch loss at step 5450: 0.145875
# Minibatch accuracy: 94.0%
# Validation accuracy: 94.8%
# Minibatch loss at step 5500: 0.670689
# Minibatch accuracy: 90.0%
# Validation accuracy: 95.0%
# Minibatch loss at step 5550: 0.112757
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.2%
# Minibatch loss at step 5600: 0.254794
# Minibatch accuracy: 96.0%
# Validation accuracy: 93.9%
# Minibatch loss at step 5650: 0.136796
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.0%
# Minibatch loss at step 5700: 0.151719
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.4%
# Minibatch loss at step 5750: 0.404256
# Minibatch accuracy: 96.0%
# Validation accuracy: 95.0%
# Minibatch loss at step 5800: 0.041734
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.4%
# Minibatch loss at step 5850: 0.114108
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.4%
# Minibatch loss at step 5900: 0.071685
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.9%
# Minibatch loss at step 5950: 0.156522
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.7%
# Minibatch loss at step 6000: 0.116597
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.8%
# Minibatch loss at step 6050: 0.102776
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.2%
# Minibatch loss at step 6100: 0.147831
# Minibatch accuracy: 96.0%
# Validation accuracy: 94.0%
# Minibatch loss at step 6150: 0.170184
# Minibatch accuracy: 96.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 6200: 0.160356
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.6%
# Minibatch loss at step 6250: 0.249940
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.9%
# Minibatch loss at step 6300: 0.185463
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.6%
# Minibatch loss at step 6350: 0.218752
# Minibatch accuracy: 98.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 6400: 0.119344
# Minibatch accuracy: 96.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 6450: 0.038958
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.8%
# Minibatch loss at step 6500: 0.075508
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.9%
# Minibatch loss at step 6550: 0.116983
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.0%
# Minibatch loss at step 6600: 0.189818
# Minibatch accuracy: 100.0%
# Validation accuracy: 95.0%
# Minibatch loss at step 6650: 0.065045
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.4%
# Minibatch loss at step 6700: 0.171359
# Minibatch accuracy: 96.0%
# Validation accuracy: 95.5%
# Minibatch loss at step 6750: 0.196243
# Minibatch accuracy: 98.0%
# Validation accuracy: 96.5%
# Minibatch loss at step 6800: 0.075044
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.7%
# Minibatch loss at step 6850: 0.049234
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.5%
# Minibatch loss at step 6900: 0.058024
# Minibatch accuracy: 100.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 6950: 0.261449
# Minibatch accuracy: 94.0%
# Validation accuracy: 93.8%
# Minibatch loss at step 7000: 0.160802
# Minibatch accuracy: 98.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 7050: 0.213720
# Minibatch accuracy: 94.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 7100: 0.128670
# Minibatch accuracy: 100.0%
# Validation accuracy: 94.3%
# Minibatch loss at step 7150: 0.290090
# Minibatch accuracy: 96.0%
# Validation accuracy: 96.1%
# Minibatch loss at step 7200: 0.229684
# Minibatch accuracy: 98.0%
# Validation accuracy: 95.2%
# Minibatch loss at step 7250: 0.194825
# Minibatch accuracy: 92.0%
# Validation accuracy: 95.8%
# Minibatch loss at step 7300: 0.143555
# Minibatch accuracy: 98.0%
# Validation accuracy: 97.0%
# Minibatch loss at step 7350: 0.049921
# Minibatch accuracy: 96.0%
# Validation accuracy: 96.0%
# Minibatch loss at step 7400: 0.234040
# Minibatch accuracy: 94.0%
# Validation accuracy: 95.9%
# Minibatch loss at step 7450: 0.141049
# Minibatch accuracy: 98.0%
# Validation accuracy: 95